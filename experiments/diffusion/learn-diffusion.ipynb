# %%
import numpy as np
import matplotlib.pyplot as plt


#print jpg image using plt

img = plt.imread('images/Maine_Coon_100.jpg')
plt.imshow(img)

# %% [markdown]
# ### Forward Process

# %%
#sample from a distribution

mu, sigma = 0, 1

x_t = np.random.normal(mu, sigma, (357, 500, 3))

#print(x_t)
print(img.shape)
print(x_t.shape)
plt.imshow(x_t)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (357, 500, 3)
# (357, 500, 3)

# %%
#scale image to [0,1]
def scale_img(img):
    return img/255.0

image = scale_img(img)

beta = 0.1
mu = np.sqrt(1-beta)*image
# print(image[0][0])
# print(mu[0][0])
noise = np.random.normal(0, np.sqrt(beta), (357, 500, 3))
x_t = mu + noise
#plt.imshow(x_t)
#plt.imshow(x_t)
# print(img)
#print(noise)

plt.imshow(x_t)


def forward_diffusion(data, t, schedule="linear", dataType="img"):
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#print hello world

print()
