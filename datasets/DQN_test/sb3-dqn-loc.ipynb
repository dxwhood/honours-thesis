# %%
from stable_baselines3 import DQN
import gymnasium as gym

# Create environment
env = gym.make('Taxi-v3')

# Initialize model
model = DQN("MlpPolicy", env, verbose=1)

# Train the agent
model.learn(total_timesteps=100000)

# Save the model
model.save("dqn_taxi_v3")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -796     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7469     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------

# %%
from stable_baselines3 import DQN
import gymnasium as gym

# Create environment
env = gym.make('FrozenLake-v1', desc=None, map_name="8x8", is_slippery=True)

# Initialize model
model = DQN(
    "MlpPolicy", 
    env, 
    verbose=1,
    learning_rate=0.001, 
    buffer_size=10000, 
    batch_size=32, 
    gamma=0.95, 
    exploration_fraction=0.1,  # fraction of entire training period over which the exploration rate is decreased
    exploration_initial_eps=1.0,  # initial value of random action probability
    exploration_final_eps=0.05,  # final value of random action probability
    train_freq=1,  # update the model every `train_freq` steps
    gradient_steps=1,  # number of gradient steps
    target_update_interval=500  # how often the target network is updated
)

# Train the agent
model.learn(total_timesteps=100000)

# Save the model
model.save("dqn_frozenlake_100K")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 56.8     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8428     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8648     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
